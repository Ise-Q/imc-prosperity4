# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import jsonpickle

# %%
# import data
prices0 = pd.read_csv("../data/prices_round_1_day_0.csv",delimiter = ";")
prices1 = pd.read_csv("../data/prices_round_1_day_-1.csv",delimiter = ";")
prices2 = pd.read_csv("../data/prices_round_1_day_-2.csv",delimiter = ";")

trades0 = pd.read_csv("../data/trades_round_1_day_0.csv",delimiter = ";")
trades1 = pd.read_csv("../data/trades_round_1_day_-1.csv",delimiter = ";")
trades2 = pd.read_csv("../data/trades_round_1_day_-2.csv",delimiter = ";")

# %%
# Out:
# count    20000.0
# mean         0.0
# std          0.0
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          0.0
# Name: profit_and_loss, dtype: float64
