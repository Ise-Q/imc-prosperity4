# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
prices_01 = pd.read_csv("prices_round_0_day_-1.csv", delimiter=";")
prices_02 = pd.read_csv("prices_round_0_day_-2.csv", delimiter=";")

trades_01 = pd.read_csv("trades_round_0_day_-1.csv", delimiter=";")
trades_02 = pd.read_csv("trades_round_0_day_-2.csv", delimiter=";")

# %%
# describe
prices_01.isna().sum(axis = 0)
# Out:
# day                    0
# timestamp              0
# product                0
# bid_price_1            0
# bid_volume_1           0
# bid_price_2            0
# bid_volume_2           0
# bid_price_3        19475
# bid_volume_3       19475
# ask_price_1            0
# ask_volume_1           0
# ask_price_2            0
# ask_volume_2           0
# ask_price_3        19482
# ask_volume_3       19482
# mid_price              0
# profit_and_loss        0
# dtype: int64
